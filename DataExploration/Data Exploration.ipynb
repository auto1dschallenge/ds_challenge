# %% [markdown]
# # Data Exploration for the Auto1 cars data set

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Read data and get basic statistics

# %%
df = pd.read_csv('./../Auto1-DS-TestData.csv',na_values = "?")
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                NaN  alfa-romero       gas        std
# 1          3                NaN  alfa-romero       gas        std
# 2          1                NaN  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base   ...     \
# 0          two  convertible          rwd           front        88.6   ...
# 1          two  convertible          rwd           front        88.6   ...
# 2          two    hatchback          rwd           front        94.5   ...
# 3         four        sedan          fwd           front        99.8   ...
# 4         four        sedan          4wd           front        99.4   ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
df.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  205.000000         164.000000  205.000000  205.000000  205.000000
# mean     0.834146         122.000000   98.756585  174.049268   65.907805
# std      1.245307          35.442168    6.021776   12.337289    2.145204
# min     -2.000000          65.000000   86.600000  141.100000   60.300000
# 25%      0.000000          94.000000   94.500000  166.300000   64.100000
# 50%      1.000000         115.000000   97.000000  173.200000   65.500000
# 75%      2.000000         150.000000  102.400000  183.100000   66.900000
# max      3.000000         256.000000  120.900000  208.100000   72.300000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  205.000000   205.000000   205.000000  201.000000  201.000000
# mean    53.724878  2555.565854   126.907317    3.329751    3.255423
# std      2.443522   520.680204    41.642693    0.273539    0.316717
# ...

# %% [markdown]
# ### Find missing values

# %%
df.describe()
for i in df.columns:
    print(str(df[i].isnull().sum()) + "\t missing entries in " + i + "  type:  " + str(df[i].dtypes))
# Out:
# 0	 missing entries in symboling  type:  int64
# 41	 missing entries in normalized-losses  type:  float64
# 0	 missing entries in make  type:  object
# 0	 missing entries in fuel-type  type:  object
# 0	 missing entries in aspiration  type:  object
# 2	 missing entries in num-of-doors  type:  object
# 0	 missing entries in body-style  type:  object
# 0	 missing entries in drive-wheels  type:  object
# 0	 missing entries in engine-location  type:  object
# 0	 missing entries in wheel-base  type:  float64
# 0	 missing entries in length  type:  float64
# 0	 missing entries in width  type:  float64
# 0	 missing entries in height  type:  float64
# 0	 missing entries in curb-weight  type:  int64
# 0	 missing entries in engine-type  type:  object
# 0	 missing entries in num-of-cylinders  type:  object
# 0	 missing entries in engine-size  type:  int64
# 0	 missing entries in fuel-system  type:  object
# 4	 missing entries in bore  type:  float64
# 4	 missing entries in stroke  type:  float64
# ...

# %% [markdown]
# normalized-losses has a large number of missing values. Check if there is any obvious pattern in how the missing values for normalized-losses are distributed.

# %%
df[df["normalized-losses"].isnull()]
# Out:
#      symboling  normalized-losses           make fuel-type aspiration  \
# 0            3                NaN    alfa-romero       gas        std
# 1            3                NaN    alfa-romero       gas        std
# 2            1                NaN    alfa-romero       gas        std
# 5            2                NaN           audi       gas        std
# 7            1                NaN           audi       gas        std
# 9            0                NaN           audi       gas      turbo
# 14           1                NaN            bmw       gas        std
# 15           0                NaN            bmw       gas        std
# 16           0                NaN            bmw       gas        std
# 17           0                NaN            bmw       gas        std
# 43           0                NaN          isuzu       gas        std
# 44           1                NaN          isuzu       gas        std
# ...

# %% [markdown]
# Distribution of prices where normalized-losses is missing versus overall distribution of prices. Check if binary feature [normalized-losses==NaN]: T/F could contain useful information.

# %%
sns.distplot(df[df["price"].notnull()]['price'], hist=True, kde=True, 
             bins=10, color = 'blue',
             hist_kws={'edgecolor':'black'})
plt.show()
# Out:
# /Users/jbrouwer/anaconda/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(df[(df["normalized-losses"].isnull()) & (df["price"].notnull())]['price'], hist=True, kde=True, 
             bins=10, color = 'blue',
             hist_kws={'edgecolor':'black'})
plt.show()
# Out:
# /Users/jbrouwer/anaconda/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ### Check distribution of price vs categorical features
# Results could be used for feature engineering/selection

# %%
cat_cols = ["make","body-style","drive-wheels","engine-type","fuel-system",
            "fuel-type","aspiration","num-of-doors","engine-location",'num-of-cylinders']
for i in cat_cols:
    ax = sns.boxplot(x=i, y="price", data=df)
    plt.title(i)
    plt.show()

# %% [markdown]
# #### Notes:
# * high cardinality of make
# * fwd and 4wd drive wheels have very similar distribution thats different from rwd
# * mpfi fuel system has a high number of outliers with very high prices
# * num-of-cylinders is basically a continous feature

# %% [markdown]
# ### Check distribution of price vs categorical features
# Results could be used for feature engineering/selection

# %%
cont_cols = ["symboling","normalized-losses","wheel-base","length","width",
            "height","curb-weight","engine-size","bore","stroke","compression-ratio",
           "horsepower","peak-rpm","city-mpg","highway-mpg","price"]
for i in cont_cols:
    ax = sns.regplot(x=i, y="price", data=df,fit_reg=True)
    plt.title(i)
    plt.show()
# Out:
# /Users/jbrouwer/anaconda/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# #### Notes:
# * symboling and normalized-losses have little clear influence on price. This makes sense given how both should be normalized to price/similar car type
# * car hight with very little correlation to price as opposed to length and widt
# * stroke and compression ratio with small correlation
#
# All statements on correlation just based on visuals

# %% [markdown]
# ### Systematically check correlations between cont features and price

# %%
corr_df=df[cont_cols ] #New dataframe to calculate correlation between numeric features
cor= corr_df.corr(method='pearson')

# %%
fig, ax =plt.subplots(figsize=(8, 6))
plt.title("Abs Correlation Plot")
sns.heatmap(np.abs(cor), mask=np.zeros_like(cor, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),square=True, ax=ax)
plt.show()

# %% [markdown]
# ### Feature selection based on correlation
# Arbitrarily define a cutoff value of 0.5 and only include features whose abs(correlation) with price is above this value to include in the model.

# %%
rel_cont_cols=cor.price[cor.price<0.5].index.tolist()
print(rel_cont_cols)
# Out:
# ['symboling', 'normalized-losses', 'height', 'stroke', 'compression-ratio', 'peak-rpm', 'city-mpg', 'highway-mpg']
